# %% [markdown]
# ### Magic Commands

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 506F-145A
#
#  Directory of C:\Users\T7\Documents\GitHub\Python_Learning
#
# 02.10.2025  14:40    <DIR>          .
# 06.09.2025  11:45    <DIR>          ..
# 08.07.2025  12:27                66 .gitattributes
# 02.10.2025  14:38    <DIR>          .ipynb_checkpoints
# 08.07.2025  14:16    <DIR>          Pyt_01_Print_Komutu
# 08.07.2025  14:56    <DIR>          Pyt_02_Değişken_ve_Atama
# 09.07.2025  12:57    <DIR>          Pyt_03_Veri_Tipleri_ve_Sayı_Tipleri
# 09.07.2025  16:14    <DIR>          Pyt_04_Yazı_Veri_Tipleri
# 11.07.2025  14:11    <DIR>          Pyt_05_Mantıki_Veri_Tipleri
# 11.07.2025  15:52    <DIR>          Pyt_06_Koleksiyon_Veri_Tipleri
# 13.07.2025  21:09    <DIR>          Pyt_07_Sabit_Koleksiyon_Veri_Tipi
# 18.07.2025  17:38    <DIR>          Pyt_08_Çok_Boyutlu_Veri_Tipleri
# 21.07.2025  19:15    <DIR>          Pyt_09_Kurs_Tekrarı_ve_Quiz
# 22.07.2025  13:23    <DIR>          Pyt_10_If_Sorguları
# ...

# %%
# %pwd
# Out:
# 'C:\\Users\\T7\\Documents\\GitHub\\Python_Learning'

# %% [markdown]
# ###  OS Modulü

# %% [markdown]
# ### Navigasyon ve İçerik Listeleme

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\T7\\Documents\\GitHub\\Python_Learning'

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitattributes',
#  '.ipynb_checkpoints',
#  'Pyt_01_Print_Komutu',
#  'Pyt_02_Değişken_ve_Atama',
#  'Pyt_03_Veri_Tipleri_ve_Sayı_Tipleri',
#  'Pyt_04_Yazı_Veri_Tipleri',
#  'Pyt_05_Mantıki_Veri_Tipleri',
#  'Pyt_06_Koleksiyon_Veri_Tipleri',
#  'Pyt_07_Sabit_Koleksiyon_Veri_Tipi',
#  'Pyt_08_Çok_Boyutlu_Veri_Tipleri',
#  'Pyt_09_Kurs_Tekrarı_ve_Quiz',
#  'Pyt_10_If_Sorguları',
#  'Pyt_11_Listelerde_For_Döngüleri',
#  'Pyt_12_Diğer_Iterable_Objelerde_For_Döngüleri',
#  'Pyt_13_While_Döngüleri',
#  'Pyt_14_Enumerate_Zip_Range_Uygulamaları',
#  'Pyt_15_Break_Continue_Pass_Komutları',
#  'Pyt_16_Fonksiyonlar_part_1',
#  'Pyt_17_Fonksiyonlar_part_2',
#  'Pyt_18_Map_Filter_ve_Lambda_İfadeleri',
#  'Pyt_19_Input_Komutu_Üzerinde_Kullanıcı_Girdisi',
#  'Pyt_20_Input_Komutu_Üzerinden_Kullanıcı_Girdisini_Onaylamak',
#  'Pyt_21_Try_Expect_Komutları_ile_Hata_Tedbiri',
#  'Pyt_22_Class_Yapısı_ve_OOP_Giriş',
#  'Pyt_23_Classlarda_Methodlar',
# ...

# %%
os.listdir('C:\\Users')
# Out:
# ['All Users',
#  'AppData',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'Public',
#  'T7']

# %%
os.chdir('C:\\Users')

# %%
os.listdir()
# Out:
# ['All Users',
#  'AppData',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'Public',
#  'T7']

# %%
os.chdir('C:\\Users\\T7\\Documents\\GitHub\\Python_Learning')

# %%
dosyalar = os.listdir()
for eleman in dosyalar:
    print(eleman)
# Out:
# .git
# .gitattributes
# .ipynb_checkpoints
# Pyt_01_Print_Komutu
# Pyt_02_Değişken_ve_Atama
# Pyt_03_Veri_Tipleri_ve_Sayı_Tipleri
# Pyt_04_Yazı_Veri_Tipleri
# Pyt_05_Mantıki_Veri_Tipleri
# Pyt_06_Koleksiyon_Veri_Tipleri
# Pyt_07_Sabit_Koleksiyon_Veri_Tipi
# Pyt_08_Çok_Boyutlu_Veri_Tipleri
# Pyt_09_Kurs_Tekrarı_ve_Quiz
# Pyt_10_If_Sorguları
# Pyt_11_Listelerde_For_Döngüleri
# Pyt_12_Diğer_Iterable_Objelerde_For_Döngüleri
# Pyt_13_While_Döngüleri
# Pyt_14_Enumerate_Zip_Range_Uygulamaları
# Pyt_15_Break_Continue_Pass_Komutları
# Pyt_16_Fonksiyonlar_part_1
# Pyt_17_Fonksiyonlar_part_2
# Pyt_18_Map_Filter_ve_Lambda_İfadeleri
# Pyt_19_Input_Komutu_Üzerinde_Kullanıcı_Girdisi
# Pyt_20_Input_Komutu_Üzerinden_Kullanıcı_Girdisini_Onaylamak
# Pyt_21_Try_Expect_Komutları_ile_Hata_Tedbiri
# Pyt_22_Class_Yapısı_ve_OOP_Giriş
# Pyt_23_Classlarda_Methodlar
# Pyt_24_Classlarda_Dunder_Methodlar_ve_Kalıtım
# Pyt_25_Dosya_ve_Klasör_Module'leri.ipynb

# %%
dosyalar = os.listdir()
for eleman in dosyalar:
    print(eleman + 'MESUT')
# Out:
# .gitMESUT
# .gitattributesMESUT
# .ipynb_checkpointsMESUT
# Pyt_01_Print_KomutuMESUT
# Pyt_02_Değişken_ve_AtamaMESUT
# Pyt_03_Veri_Tipleri_ve_Sayı_TipleriMESUT
# Pyt_04_Yazı_Veri_TipleriMESUT
# Pyt_05_Mantıki_Veri_TipleriMESUT
# Pyt_06_Koleksiyon_Veri_TipleriMESUT
# Pyt_07_Sabit_Koleksiyon_Veri_TipiMESUT
# Pyt_08_Çok_Boyutlu_Veri_TipleriMESUT
# Pyt_09_Kurs_Tekrarı_ve_QuizMESUT
# Pyt_10_If_SorgularıMESUT
# Pyt_11_Listelerde_For_DöngüleriMESUT
# Pyt_12_Diğer_Iterable_Objelerde_For_DöngüleriMESUT
# Pyt_13_While_DöngüleriMESUT
# Pyt_14_Enumerate_Zip_Range_UygulamalarıMESUT
# Pyt_15_Break_Continue_Pass_KomutlarıMESUT
# Pyt_16_Fonksiyonlar_part_1MESUT
# Pyt_17_Fonksiyonlar_part_2MESUT
# Pyt_18_Map_Filter_ve_Lambda_İfadeleriMESUT
# Pyt_19_Input_Komutu_Üzerinde_Kullanıcı_GirdisiMESUT
# Pyt_20_Input_Komutu_Üzerinden_Kullanıcı_Girdisini_OnaylamakMESUT
# Pyt_21_Try_Expect_Komutları_ile_Hata_TedbiriMESUT
# Pyt_22_Class_Yapısı_ve_OOP_GirişMESUT
# Pyt_23_Classlarda_MethodlarMESUT
# ...

# %% [markdown]
# ### Yeni Eleman Oluşturma, İsim Değiştirme ve Silme

# %%
os.mkdir('C:\\Users\\T7\\Documents\\GitHub\\Python_Learning\\Pyt_25_Dosya_ve_Klasör_Moduleleri\\deneme')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 os.mkdir('C:\\Users\\T7\\Documents\\GitHub\\Python_Learning\\Pyt_25_Dosya_ve_Klasör_Moduleleri\\deneme')
#
# NameError: name 'os' is not defined

# %%
## os.O_RDONLY - Read Only         - Sadece Oku
## os.O_WEONLY - Write Only        - Sadece Yaz
## os.O_RDWR   - Read and Write    - Oku ve Yaz 
## os.O_CREAT  - Creat             - Oluştur
